# %% [markdown]
# # Welcome to Data World

# %% [markdown]
# <ul>
#     <li>In the Present World every thing links with data. we are using data everywhere.</li>
#     <li>All Industries are looking the people those who can undertsand and interpret data and to give meaningful insights.</li>
# </ul>

# %% [markdown]
# ## According to Harward Business Review

# %% [markdown]
# ![ecomistJournel.PNG](attachment:ecomistJournel.PNG)

# %% [markdown]
# ## Revolutionized past to present on understanding of data

# %% [markdown]
# ![need-for-data-science.png](attachment:need-for-data-science.png)

# %% [markdown]
# <h2>Data Scientist is more than just organizing data</h2>

# %% [markdown]
# <p><b style="font-size: 30px;">Data scientists</b> tackle questions about the future. They start with big data, characterized by the three V’s: volume, variety and velocity. Then, they use it as fodder for algorithms and models. The most cutting-edge data scientists, working in machine learning and AI, make models that automatically self-improve, noting and learning from their mistakes.</p>

# %% [markdown]
# ![ds.png](attachment:ds.png)

# %% [markdown]
# ![whatisDS.PNG](attachment:whatisDS.PNG)

# %% [markdown]
# # Lets see most popular Data science programming languages

# %% [markdown]
# ![ds%20pl.jpg](attachment:ds%20pl.jpg)

# %% [markdown]
# ## Applications of Data Science

# %% [markdown]
# Data scientists have changed almost every industry. In medicine, their algorithms help predict patient side effects. In sports, their models and metrics have redefined “athletic potential.” Data science has even tackled traffic, with route-optimizing models that capture typical rush hours and weekend lulls.

# %% [markdown]
# ### List of Data Science applications

# %% [markdown]
# ![Data-Science-Applications-01.jpg](attachment:Data-Science-Applications-01.jpg)

# %% [markdown]
# ### In Finance

# %% [markdown]
# ![Applications-of-data-science-in-Finance.jpg](attachment:Applications-of-data-science-in-Finance.jpg)

# %% [markdown]
# ## Before Concluding Lets See Your Daily Job of Data scientist

# %% [markdown]
# ![dsprocess.PNG](attachment:dsprocess.PNG)
