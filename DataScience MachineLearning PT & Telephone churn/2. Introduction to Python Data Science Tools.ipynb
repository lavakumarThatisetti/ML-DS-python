# %% [markdown]
# # Hi, Welcome to Introduction to  Data Science Tools

# %% [markdown]
# ![dstools.PNG](attachment:dstools.PNG)

# %% [markdown]
# ## Lets see Most Important libraries in Python

# %% [markdown]
# ### For Data Analysis and Visualization

# %% [markdown]
# <ul>
#     <li>Pandas</li>
#     <li>Numpy</li>
#     <li>Scipy</li>
#     <li>BeautifulSoup</li>
#     <li>Matplotlib</li>
#     <li>Seaborn</li>
#     <li>Plotly</li>
#     <li>Statmodels</li>
#     <li>SciKit-Learn</li>
# </ul>

# %% [markdown]
# ### Big Data Processing

# %% [markdown]
# <ul>
#     <li>Pyspark</li>
#     <li>Kafka Python</li>
#     <li>Pydoop</li>
#     <li>Bonobo</li>
#     <li>Apache Airflow</li>
# </ul>

# %% [markdown]
# ### For Data Science and ML

# %% [markdown]
# <ul>
#     <li>Statmodels</li>
#     <li>SciKit-Learn</li>
#     <li>NLTK</li>
# </ul>

# %% [markdown]
# ### For Deep Learning

# %% [markdown]
# <ul>
#     <li>Tensor Flow</li>
#     <li>PyTorch</li>
#     <li>Keras</li>
#     <li>OpenCV</li>
# </ul>

# %% [markdown]
# ## Still lot more Libraries ... [ Python has warehouse of DS & ML Libraries]
